# %%
import pandas as pd
import os
import numpy as np
from loguru import logger
import sys
# Load dateloader
from scipy.stats import gaussian_kde
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
import contact_state_classification as csc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
experiment_dir = csc.config.path["experiment_dir"]
cs_classifier = csc.CSClassifier(experiment_dir=experiment_dir, dataset_name=csc.config.path["dataset_name"])
# Out:
# 2021-11-21 19:49:35.809 | INFO     | contact_state_classification.cs_classifier:get_dataset_information:110 - All classes from the dataset RoboticsProject2510_2 are ['CS1' 'CS2' 'CS3' 'CS5' 'CS6']:

# %%
# def show_plots(col):
#     cs1_df = cs_classifier.csd_data_df.loc[cs1_idx_list][col]
#     cs3_df = cs_classifier.csd_data_df.loc[cs3_idx_list][col]
#     cs5_df = cs_classifier.csd_data_df.loc[cs5_idx_list][col]
#     cs6_df = cs_classifier.csd_data_df.loc[cs6_idx_list][col]
#
#     # cs1_df_theta = pd.DataFrame([*cs1_df], columns = ['act' + str(x) for x in range(1, 13)])
#
#     df_cs1 = pd.DataFrame({'CS1': [item for item in cs1_idx_list for i in range(12)],
#                            'action': list(range(1, 13)) * len(cs1_idx_list),
#                            col: pd.DataFrame([*cs1_df]).to_numpy().flatten()})
#
#     df_cs3 = pd.DataFrame({'CS3': [item for item in cs3_idx_list for i in range(12)],
#                            'action': list(range(1, 13)) * len(cs3_idx_list),
#                            col: pd.DataFrame([*cs3_df]).to_numpy().flatten()})
#
#     df_cs5 = pd.DataFrame({'CS5': [item for item in cs5_idx_list for i in range(12)],
#                            'action': list(range(1, 13)) * len(cs5_idx_list),
#                            col: pd.DataFrame([*cs5_df]).to_numpy().flatten()})
#
#     df_cs6 = pd.DataFrame({'CS6': [item for item in cs6_idx_list for i in range(12)],
#                            'action': list(range(1, 13)) * len(cs6_idx_list),
#                            col: pd.DataFrame([*cs6_df]).to_numpy().flatten()})
#
#     sns_plot = sns.relplot(x="action", y=col, hue="CS1",
#                            dashes=False, markers=True, kind="line", data=df_cs1)
#     sns_plot.savefig("cs1.png")
#
#     sns_plot = sns.relplot(x="action", y=col, hue="CS3",
#                            dashes=False, markers=True, kind="line", data=df_cs3)
#     sns_plot.savefig("cs3.png")
#
#     sns_plot = sns.relplot(x="action", y=col, hue="CS5",
#                            dashes=False, markers=True, kind="line", data=df_cs5)
#     sns_plot.savefig("cs5.png")
#
#     sns_plot = sns.relplot(x="action", y=col, hue="CS6",
#                            dashes=False, markers=True, kind="line", data=df_cs6)
#     sns_plot.savefig("cs6.png")

# %%
import base64
from facets_overview.generic_feature_statistics_generator import GenericFeatureStatisticsGenerator

gfsg = GenericFeatureStatisticsGenerator()
proto = gfsg.ProtoFromDataFrames([{'name': 'train', 'table': cs_classifier.X_df}])
protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")

sprite_size = 32 if len(cs_classifier.X_df.index) > 50000 else 64

jsonstr = cs_classifier.X_df.to_json(orient='records')

# %%
# from IPython.core.display import display, HTML

# HTML_TEMPLATE = """
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html" >
#         <facets-overview id="elem"></facets-overview>
#         <script>
#           document.querySelector("#elem").protoInput = "{protostr}";
#         </script>"""
# html = HTML_TEMPLATE.format(protostr=protostr)
# display(HTML(html))

# %%
# Display the Dive visualization for the training data.
from IPython.core.display import display, HTML

HTML_TEMPLATE = """
        <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
        <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="1000"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="1000"></facets-dive>
#         <script>
#           var data = [{"act0 dist":0.0000895197,"act1 dist":0.0162565277,"act2 dist":0.0171398847,"act3 dist":0.0173243722,"act4 dist":0.002483388,"act5 dist":0.0028817288,"act6 dist":0.0033645707,"act7 dist":0.0047364508,"act8 dist":0.0034624364,"act9 dist":0.0025762449,"act10 dist":0.0025254534,"act11 dist":0.0025199427,"act0 obs_ee_theta":2.5715733388,"act1 obs_ee_theta":0.0604252981,"act2 obs_ee_theta":0.0709805851,"act3 obs_ee_theta":0.0686857509,"act4 obs_ee_theta":0.109221611,"act5 obs_ee_theta":1.4545148015,"act6 obs_ee_theta":-3.0242065771,"act7 obs_ee_theta":-1.7881838557,"act8 obs_ee_theta":2.9962342154,"act9 obs_ee_theta":3.030901672,"act10 obs_ee_theta":3.0414474919,"act11 obs_ee_theta":3.0751079655,"act0 obs_ee_phi":1.0234513446,"act1 obs_ee_phi":2.9849803108,"act2 obs_ee_phi":2.9737135602,"act3 obs_ee_phi":2.9720600468,"act4 obs_ee_phi":2.1203561869,"act5 obs_ee_phi":1.4585912472,"act6 obs_ee_phi":1.1629604391,"act7 obs_ee_phi":1.7316144248,"act8 obs_ee_phi":0.3942473049,"act9 obs_ee_phi":0.3717666379,"act10 obs_ee_phi":0.3778126519,"act11 obs_ee_phi":0.3676100473,"act_0 joint_0 error_q":0.0000082403,"act_0 joint_1 error_q":0.0000324845,"act_0 joint_2 error_q":-0.0000166595,"act_0 joint_3 error_q":-0.0000963211,"act_0 joint_4 error_q":0.0000025481,"act_0 joint_5 error_q":-0.000180006,"act_0 joint_6 error_q":0.0000011921,"act_1 joint_0 error_q":0.0000299364,"act_1 joint_1 error_q":-0.0003301799,"act_1 joint_2 error_q":0.0003535151,"act_1 joint_3 error_q":0.0001573563,"act_1 joint_4 error_q":0.0000033379,"act_1 joint_5 error_q":-0.0016069412,"act_1 joint_6 error_q":-0.0000032187,"act_2 joint_0 error_q":0.0000628978,"act_2 joint_1 error_q":-0.0003018677,"act_2 joint_2 error_q":0.0005384535,"act_2 joint_3 error_q":0.0001711845,"act_2 joint_4 error_q":0.0000105724,"act_2 joint_5 error_q":-0.001554966,"act_2 joint_6 error_q":-0.0000017881,"act_3 joint_0 error_q":0.0000667572,"act_3 joint_1 error_q":-0.0003474653,"act_3 joint_2 error_q":0.0005782247,"act_3 joint_3 error_q":0.0001671314,"act_3 joint_4 error_q":0.0000113249,"act_3 joint_5 error_q":-0.001639843,"act_3 joint_6 error_q":-0.0000032187,"act_4 joint_0 error_q":0.0002721548,"act_4 joint_1 error_q":-0.0002842844,"act_4 joint_2 error_q":-0.0000044852,"act_4 joint_3 error_q":0.000852108,"act_4 joint_4 error_q":0.0000199825,"act_4 joint_5 error_q":-0.0015099049,"act_4 joint_6 error_q":-0.0000003576,"act_5 joint_0 error_q":-0.0000099987,"act_5 joint_1 error_q":-0.0004557371,"act_5 joint_2 error_q":-0.0013097823,"act_5 joint_3 error_q":0.0002396107,"act_5 joint_4 error_q":-0.0001193285,"act_5 joint_5 error_q":-0.0022575855,"act_5 joint_6 error_q":0.0000004768,"act_6 joint_0 error_q":0.000095889,"act_6 joint_1 error_q":-0.0006946325,"act_6 joint_2 error_q":-0.0002612323,"act_6 joint_3 error_q":-0.0009117126,"act_6 joint_4 error_q":-0.0001045018,"act_6 joint_5 error_q":-0.0021128654,"act_6 joint_6 error_q":0.000009656,"act_7 joint_0 error_q":0.0005429685,"act_7 joint_1 error_q":-0.0005289912,"act_7 joint_2 error_q":0.0015773326,"act_7 joint_3 error_q":0.0004007816,"act_7 joint_4 error_q":-0.0001392215,"act_7 joint_5 error_q":-0.0015239716,"act_7 joint_6 error_q":0.000015974,"act_8 joint_0 error_q":0.0004244447,"act_8 joint_1 error_q":0.0013050139,"act_8 joint_2 error_q":0.0007749796,"act_8 joint_3 error_q":0.0002794266,"act_8 joint_4 error_q":-0.0001545325,"act_8 joint_5 error_q":-0.0013883114,"act_8 joint_6 error_q":0.0000137091,"act_9 joint_0 error_q":0.0003746599,"act_9 joint_1 error_q":0.0014604926,"act_9 joint_2 error_q":0.0004012436,"act_9 joint_3 error_q":0.0001592636,"act_9 joint_4 error_q":-0.0001638979,"act_9 joint_5 error_q":-0.0014390945,"act_9 joint_6 error_q":0.0000091791,"act_10 joint_0 error_q":0.0003289133,"act_10 joint_1 error_q":0.0014928877,"act_10 joint_2 error_q":0.0002247095,"act_10 joint_3 error_q":0.0000758171,"act_10 joint_4 error_q":-0.0001646131,"act_10 joint_5 error_q":-0.0014765263,"act_10 joint_6 error_q":0.0000075102,"act_11 joint_0 erro ...

# %%
# import hiplot as hip
#
# hip.Experiment.from_dataframe(cs1_df_theta).display()

# %%
# show_plots("d_ee_theta")
#

# %%
# show_plots("d_ee_phi")

# %%
# show_plots("obs_ee_theta")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8187/739043261.py in <module>
# ----> 1 show_plots("obs_ee_theta")
#       2
#
# NameError: name 'show_plots' is not defined

# %%
# show_plots("obs_ee_phi")

# %%
# show_plots("dist")
